# %%
import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
from keras.models import load_model
import numpy
import tflearn
import tensorflow
import random
# Out:
# Using TensorFlow backend.
# /home/rukesh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rukesh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rukesh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import json
with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/j.json') as file:
    data1 = json.load(file)
    
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/afternoon.json') as file:
#     data2 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/compensation.json') as file:
#     data3 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/evening.json') as file:
#     data4 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/farfromrouter.json') as file:
#     data5 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/fup.json') as file:
#     data6 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/gaming.json') as file:
#     data7 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/gamingwin.json') as file:
#     data8 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/greeting.json') as file:
#     data9 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/hosting.json') as file:
#     data10 = json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/morning.json') as file:
#     data11= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/nettv.json') as file:
#     data12= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/nointernet.json') as file:
#     data13= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/offensive.json') as file:
#     data14= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/online.json') as file:
#     data15= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/portforward.json') as file:
#     data16= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/safenet.json') as file:
#     data17= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/secondaryrouterconfiguration.json') as file:
#     data18= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/slowconnection.json') as file:
#     data19= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/thank.json') as file:
#     data20= json.load(file)
    
# with open('/home/rukesh/Documents/Retrievalbased_chatbot_data/finalretrivaldata/dataformating/json_only/wifipass.json') as file:
#     data21= json.load(file)

# %%
words1 = list()
labels1 = list()
docs_x1 = list()
docs_y1 = list()

# words2 = list()
# labels2 = list()
# docs_x2 = list()
# docs_y2 = list()

# words3= list()
# labels3 = list()
# docs_x3 = list()
# docs_y3 = list()

# words4 = list()
# labels4 = list()
# docs_x4 = list()
# docs_y4 = list()

# words5 = list()
# labels5 = list()
# docs_x5 = list()
# docs_y5 = list()

# words6= list()
# labels6 = list()
# docs_x6 = list()
# docs_y6 = list()

# words7= list()
# labels7 = list()
# docs_x7 = list()
# docs_y7 = list()

# words8= list()
# labels8 = list()
# docs_x8 = list()
# docs_y8 = list()

# words9= list()
# labels9 = list()
# docs_x9 = list()
# docs_y9 = list()

# words10= list()
# labels10 = list()
# docs_x10= list()
# docs_y10= list()

# words11 = list()
# labels11 = list()
# docs_x11 = list()
# docs_y11 = list()

# words12 = list()
# labels12 = list()
# docs_x12 = list()
# docs_y12 = list()

# words13 = list()
# labels13 = list()
# docs_x13 = list()
# docs_y13 = list()

# words14 = list()
# labels14 = list()
# docs_x14 = list()
# docs_y14 = list()

# words15 = list()
# labels15 = list()
# docs_x15 = list()
# docs_y15 = list()

# words16 = list()
# labels16 = list()
# docs_x16 = list()
# docs_y16 = list()

# words17 = list()
# labels17 = list()
# docs_x17 = list()
# docs_y17 = list()

# words18 = list()
# labels18 = list()
# docs_x18 = list()
# docs_y18 = list()

# words19 = list()
# labels19 = list()
# docs_x19 = list()
# docs_y19 = list()

# words20 = list()
# labels20 = list()
# docs_x20 = list()
# docs_y20 = list()

# words21 = list()
# labels21 = list()
# docs_x21 = list()
# docs_y21 = list()

words = list()
labels = list()
docs_x = list()
docs_y = list()

# %%
for intent in data1['intents']:
    for pattern in intent['patterns']:
        wrds1 = nltk.word_tokenize(pattern)
        words1.extend(wrds1)
        docs_x1.append(wrds1)
        docs_y1.append(intent["tag"])
        
    if intent['tag'] not in labels1:
        labels1.append(intent['tag'])
        
words.extend(words1)
labels.extend(labels1)
docs_x.extend(docs_x1)
docs_y.extend(docs_y1)


        
# for intent in data2['intents']:
#     for pattern in intent['patterns']:
#         wrds2 = nltk.word_tokenize(pattern)
#         words2.extend(wrds2)
#         docs_x2.append(wrds2)
#         docs_y2.append(intent["tag"])
        
#     if intent['tag'] not in labels2:
#         labels2.append(intent['tag'])

        
# words.extend(words2)
# labels.extend(labels2)
# docs_x.extend(docs_x2)
# docs_y.extend(docs_y2)
        
# for intent in data3['intents']:
#     for pattern in intent['patterns']:
#         wrds3 = nltk.word_tokenize(pattern)
#         words3.extend(wrds3)        
#         docs_x3.append(wrds3)
#         docs_y3.append(intent["tag"])
        
#     if intent['tag'] not in labels3:
#         labels3.append(intent['tag'])
        
# words.extend(words3)
# labels.extend(labels3)
# docs_x.extend(docs_x3)
# docs_y.extend(docs_y3)
        
# for intent in data4['intents']:
#     for pattern in intent['patterns']:
#         wrds4 = nltk.word_tokenize(pattern)
#         words4.extend(wrds4)
#         docs_x4.extend(wrds4)
#         docs_y4.extend(intent["tag"])
        
#     if intent['tag'] not in labels4:
#         labels4.append(intent['tag'])
        
        
# words.extend(words4)
# labels.extend(labels4)
# docs_x.extend(docs_x4)
# docs_y.extend(docs_y4)
        
# for intent in data5['intents']:
#     for pattern in intent['patterns']:
#         wrds5 = nltk.word_tokenize(pattern)
#         words5.extend(wrds5)        
#         docs_x5.append(wrds5)
#         docs_y5.append(intent["tag"])
        
#     if intent['tag'] not in labels5:
#         labels5.append(intent['tag'])
        
# words.extend(words6)
# labels.extend(labels6)
# docs_x.extend(docs_x6)
# docs_y.extend(docs_y6)
        
# for intent in data7['intents']:
#     for pattern in intent['patterns']:
#         wrds7 = nltk.word_tokenize(pattern)
#         words7.extend(wrds7)        
#         docs_x7.append(wrds7)
#         docs_y7.append(intent["tag"])
        
#     if intent['tag'] not in labels7:
#         labels7.append(intent['tag'])
        
# words.extend(words7)
# labels.extend(labels7)
# docs_x.extend(docs_x7)
# docs_y.extend(docs_y7)
        
# for intent in data8['intents']:
#     for pattern in intent['patterns']:
#         wrds8 = nltk.word_tokenize(pattern)
#         words8.extend(wrds8)        
#         docs_x8.append(wrds8)
#         docs_y8.append(intent["tag"])
        
#     if intent['tag'] not in labels8:
#         labels8.append(intent['tag'])
        
# words.extend(words8)
# labels.extend(labels8)
# docs_x.extend(docs_x8)
# docs_y.extend(docs_y8)
        
# for intent in data9['intents']:
#     for pattern in intent['patterns']:
#         wrds9 = nltk.word_tokenize(pattern)
#         words9.extend(wrds9)
#         docs_x9.append(wrds9)
#         docs_y9.append(intent["tag"])
        
#     if intent['tag'] not in labels9:
#         labels9.append(intent['tag'])
        
# words.extend(words9)
# labels.extend(labels9)
# docs_x.extend(docs_x9)
# docs_y.extend(docs_y9)
        
# for intent in data10['intents']:
#     for pattern in intent['patterns']:
#         wrds10 = nltk.word_tokenize(pattern)
#         words10.extend(wrds10)
#         docs_x10.append(wrds10)
#         docs_y10.append(intent["tag"])
        
#     if intent['tag'] not in labels10:
#         labels10.append(intent['tag'])
        
# words.extend(words10)
# labels.extend(labels10)
# docs_x.extend(docs_x10)
# docs_y.extend(docs_y10)
        
# for intent in data11['intents']:
#     for pattern in intent['patterns']:
#         wrds11 = nltk.word_tokenize(pattern)
#         words11.extend(wrds11)        
#         docs_x11.append(wrds11)
#         docs_y11.append(intent["tag"])
        
#     if intent['tag'] not in labels11:
#         labels11.append(intent['tag'])
        
# words.extend(words11)
# labels.extend(labels11)
# docs_x.extend(docs_x11)
# docs_y.extend(docs_y11)
        
# for intent in data12['intents']:
#     for pattern in intent['patterns']:
#         wrds12 = nltk.word_tokenize(pattern)
#         words12.extend(wrds12)        
#         docs_x12.append(wrds12)
#         docs_y12.append(intent["tag"])
        
#     if intent['tag'] not in labels12:
#         labels12.append(intent['tag'])
        
# words.extend(words12)
# labels.extend(labels12)
# docs_x.extend(docs_x12)
# docs_y.extend(docs_y12)
        
# for intent in data13['intents']:
#     for pattern in intent['patterns']:
#         wrds13 = nltk.word_tokenize(pattern)
#         words13.extend(wrds13)    
#         docs_x13.append(wrds13)
#         docs_y13.append(intent["tag"])
        
#     if intent['tag'] not in labels13:
#         labels13.append(intent['tag'])
        
# words.extend(words13)
# labels.extend(labels13)
# docs_x.extend(docs_x13)
# docs_y.extend(docs_y13)
        
# for intent in data14['intents']:
#     for pattern in intent['patterns']:
#         wrds14 = nltk.word_tokenize(pattern)
#         words14.extend(wrds14)        
#         docs_x14.append(wrds14)
#         docs_y14.append(intent["tag"])
        
#     if intent['tag'] not in labels14:
#         labels14.append(intent['tag'])
        
# words.extend(words14)
# labels.extend(labels14)
# docs_x.extend(docs_x14)
# docs_y.extend(docs_y14)
        
# for intent in data15['intents']:
#     for pattern in intent['patterns']:
#         wrds15 = nltk.word_tokenize(pattern)
#         words15.extend(wrds15)       
#         docs_x15.append(wrds15)
#         docs_y15.append(intent["tag"])
        
#     if intent['tag'] not in labels15:
#         labels15.append(intent['tag'])
        
# words.extend(words15)
# labels.extend(labels15)
# docs_x.extend(docs_x15)
# docs_y.extend(docs_y15)
        
# for intent in data16['intents']:
#     for pattern in intent['patterns']:
#         wrds16 = nltk.word_tokenize(pattern)
#         words16.extend(wrds16)        
#         docs_x16.append(wrds16)
#         docs_y16.append(intent["tag"])
        
#     if intent['tag'] not in labels16:
#         labels16.append(intent['tag'])
        
# words.extend(words16)
# labels.extend(labels16)
# docs_x.extend(docs_x16)
# docs_y.extend(docs_y16)


# for intent in data17['intents']:
#     for pattern in intent['patterns']:
#         wrds17 = nltk.word_tokenize(pattern)
#         words17.extend(wrds17)
#         docs_x17.append(wrds17)
#         docs_y17.append(intent["tag"])
        
#     if intent['tag'] not in labels17:
#         labels17.append(intent['tag'])
        
# words.extend(words17)
# labels.extend(labels17)
# docs_x.extend(docs_x17)
# docs_y.extend(docs_y17)
        
        
# for intent in data18['intents']:
#     for pattern in intent['patterns']:
#         wrds18 = nltk.word_tokenize(pattern)
#         words18.extend(wrds18)       
#         docs_x18.append(wrds18)
#         docs_y18.append(intent["tag"])
        
#     if intent['tag'] not in labels18:
#         labels18.append(intent['tag'])
        
# words.extend(words18)
# labels.extend(labels18)
# docs_x.extend(docs_x18)
# docs_y.extend(docs_y18)
        
# for intent in data19['intents']:
#     for pattern in intent['patterns']:
#         wrds19 = nltk.word_tokenize(pattern)
#         words19.extend(wrds19)       
#         docs_x19.append(wrds19)
#         docs_y19.append(intent["tag"])
        
#     if intent['tag'] not in labels19:
#         labels19.append(intent['tag'])
        
        
# words.extend(words19)
# labels.extend(labels19)
# docs_x.extend(docs_x19)
# docs_y.extend(docs_y19)
        
        
# for intent in data20['intents']:
#     for pattern in intent['patterns']:
#         wrds20 = nltk.word_tokenize(pattern)
#         words20.extend(wrds20)        
#         docs_x20.append(wrds20)
#         docs_y20.append(intent["tag"])
        
#     if intent['tag'] not in labels20:
#         labels20.append(intent['tag'])
        
# words.extend(words20)
# labels.extend(labels20)
# docs_x.extend(docs_x20)
# docs_y.extend(docs_y20)
        
        
# for intent in data21['intents']:
#     for pattern in intent['patterns']:
#         wrds21 = nltk.word_tokenize(pattern)
#         words21.extend(wrds21)
#         docs_x21.append(wrds21)
#         docs_y21.append(intent["tag"])
        
#     if intent['tag'] not in labels21:
#         labels21.append(intent['tag'])
        
# words.extend(words21)
# labels.extend(labels21)
# docs_x.extend(docs_x21)
# docs_y.extend(docs_y21)

# %%
print(words)
# Out:
# ['i', 'want', 'to', 'hide', 'my', 'wifi', 'ssid', 'bro', '.', 'could', 'you', 'guide', 'me', 'to', 'hide', 'the', 'wifi', 'password', '?', 'thank', 'you', 'for', 'the', 'coorporation', '.', 'okay', 'you', 'really', 'suprise', 'me', '.', 'you', 'are', 'such', 'an', 'insanse', '.', '🤣️🤣️🤣️🤣️', 'thank', 'you', 'for', 'your', 'coorporation', 'and', 'guidance', '.', 'ummm', 'well', 'its', 'working', 'okay', 'let', 'me', 'check', 'thank', 'you', 'brother', 'thank', 'you', 'thank', 'you', 'so', 'much', 'for', 'your', 'support', '.', 'okay', 'thank', 'you', 'so', 'much', 'okay', 'okay', 'bro', 'catch', 'you', 'later', 'well', 'done', 'my', 'internet', 'is', 'not', 'working', 'well', 'for', 'a', 'past', 'few', 'days', '.', 'i', 'am', 'facing', 'the', 'internet', 'problem', 'from', 'past', 'one', 'month', '.', 'oi', 'sunta', '.', 'why', 'is', 'your', 'internet', 'not', 'working', '.', 'i', 'am', 'having', 'issue', 'in', 'the', 'gaming', 'for', 'the', 'past', 'one', 'month', '.', 'are', 'you', 
# ...

# %%
# len(words)
len(labels)
labels
# Out:
# ['changepasswordfrommobile',
#  'thankyou',
#  'slowconnection',
#  'secondaryrouter',
#  'safenet',
#  'portforward',
#  'onlineservices',
#  'offensive',
#  'nointernetconnection',
#  'nettv',
#  'goodmorning',
#  'hosting',
#  'greeting',
#  'gamingwinprice',
#  'onlinegaming',
#  'fup',
#  'farfromrouter',
#  'goodevening',
#  'compensation',
#  'afternoon',
#  'account']

# %%
words = [stemmer.stem(w.lower()) for w in words if w != "?"]
words = sorted(list(set(words)))
print(words)
# Out:
# ['%', "''", ',', '.', '100', '11', '23', '5', '7', '8', '``', 'a', 'abl', 'about', 'abov', 'access', 'account', 'act', 'ad', 'aft', 'afternoon', 'al', 'also', 'altern', 'am', 'amount', 'an', 'and', 'anoth', 'any', 'anyon', 'apolog', 'app/application', 'application/app', 'apply', 'ar', 'as', 'at', 'avoid', 'back', 'be', 'been', 'bhast', 'bitch', 'black', 'block', 'boro', 'branch', 'bro', 'broth', 'brow', 'brows', 'buddy', 'but', 'button', 'ca', 'cabl', 'cal', 'cam', 'can', "cant't", 'catch', 'certain', 'chang', 'channel', 'check', 'claim', 'cli', 'col', 'com', 'compens', 'complet', 'concern', 'connect', 'cont', 'contact', 'contain', 'context', 'coorp', 'could', 'cred', 'csgo', 'cur', 'custom', 'cut', 'dam', 'day', 'decl', 'depart', 'detail', 'dev', 'develop', 'diagnos', 'did', 'diff', 'do', 'docu', 'doe', 'don', 'down', 'downloa', 'download', 'due', 'dump', 'eat', 'educ', 'elab', 'elig', 'esc', 'espec', 'ev', 'ex', 'expir', 'explain', 'explaind', 'extend', 'fac', 'facebook', 'fair', '
# ...

# %%
labels = sorted(labels)
out_empty = [0 for _ in range(len(labels))]
print(labels)
# Out:
# ['account', 'afternoon', 'changepasswordfrommobile', 'compensation', 'farfromrouter', 'fup', 'gamingwinprice', 'goodevening', 'goodmorning', 'greeting', 'hosting', 'nettv', 'nointernetconnection', 'offensive', 'onlinegaming', 'onlineservices', 'portforward', 'safenet', 'secondaryrouter', 'slowconnection', 'thankyou']

# %%
training =list()
output = list()
for x, doc in enumerate(docs_x):
    bag = list()
    wrds = [stemmer.stem(w.lower()) for w in doc]
#     print(wrds)
    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)
    output_row = out_empty[:]
    print(docs_y)
    output_row[labels.index(docs_y[x])] = 1
    training.append(bag)
    output.append(output_row)
training = numpy.array(training)
output = numpy.array(output)
# Out:
# ['changepasswordfrommobile', 'changepasswordfrommobile', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'thankyou', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'slowconnection', 'secondaryrouter', 'secondaryrouter', 'secondaryrouter', 'secondaryrouter', 'secondaryrouter', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'safenet', 'portforward', 'portforward', 'portforward', 'portforward', 'portforward', 'onlineservices', 'onlineservices', 'onlineser
# ...

# %%
tensorflow.reset_default_graph()
net = tflearn.input_data(shape=[None, len(training[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(output[0]), activation="softmax")
net = tflearn.regression(net)
model = tflearn.DNN(net)
# Out:
# WARNING:tensorflow:From /home/rukesh/.local/lib/python3.6/site-packages/tflearn/layers/core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/rukesh/.local/lib/python3.6/site-packages/tflearn/initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/rukesh/.local/lib/python3.6/site-packages/tflearn/optimizers.py:238: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/rukesh/.local/lib/python3.6/site-packages/tflearn/objectives.py:66: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# ...

# %%
# model.fit(training, output, n_epoch=2000, batch_size=16, show_metric=True)
# model.save("model.h5")

# %%
model.load('model.h5')
print(model)
# Out:
# WARNING:tensorflow:From /home/rukesh/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /home/rukesh/Documents/final_year/FYP/Retrieval_based_chatbot/model.h5
# ...

# %%
def bag_of_words(s, words):
    bag = [0 for _ in range(len(words))]

    s_words = nltk.word_tokenize(s)
    s_words = [stemmer.stem(word.lower()) for word in s_words]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1
            
    return numpy.array(bag)


def chat():
    print("Start talking with the bot (type quit to stop)!")
    while True:
        inp = input("Questions:  ")
        if inp.lower() == "quit":
            break

        results = model.predict([bag_of_words(inp, words)])
        results_index = numpy.argmax(results)
        tag = labels[results_index]

        for tg in data1["intents"]:
            if tg['tag'] == tag:
                responses = tg['responses']

        print(random.choice(responses))

# %%
chat()
# Out:
# Start talking with the bot (type quit to stop)!
# Questions:   hi
# hello sir/mam.
# Questions:  nasmastae
# okay sir
# Questions:  helloe
# hello there, how can i help you.
# Questions:  how can i help you?
# welcome sir/mam
# Questions:  i am facing internet connection issue.
# sir/mam the download speed also matter from the server.if the server has limit the speed. we can't do anything. as you have already tested the speed as well as the download speed of the other site too. there is no issue from the isp site.
# Questions:  hello
# hi there
# Questions:  how are you?
# hello sir/mam. how can we assist you?
# Questions:  no internet connection.
# thank you sir/mam.
# Questions:  are you serious
# hi there
# Questions:  hi
# how can i help you?
# Questions:  sales
# if you continue using such offensive and vulgar words to seek our assistance. we will be compelled to blacklist you from online support services. thank you!
# Questions:  provide me sales number
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3e30156ce8ad> in <module>
# ----> 1 pwd
#       2
#
# NameError: name 'pwd' is not defined
